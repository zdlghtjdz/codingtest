# %%
# 개임 개발

def char_point(cha_p) :
    if cha_p == 0:
        cha_p = 3
    else :
        cha_p -= 1

    return cha_p

#  북 0 동 1 남 2 서 3
def char_p_rev(cha_x, cha_y, cha_p) :
    if cha_p == 0 :
        cha_y += 1
    elif cha_p == 1:
        cha_x -= 1
    elif cha_p == 2 :
        cha_y -= 1
    elif cha_p == 3 :
        cha_x += 1
    
    return cha_x, cha_y, cha_p

# N X M 직사각형 맵

N, M = map(int, input().split())

cha_x, cha_y, cha_p = map(int, input().split())

game_map = list()
for i in range(M) :
    game_map.append(list(map(int, input().split())))

#  캐릭터는 현재방향을 기준으로 반시계방향으로 갈곳을 정한다.
#  북 0 동 1 남 2 서 3
#  육지 0 바다 1
#  캐릭터 왼쪽(-1)에 가보지 않은 칸이 있다면 왼쪽 방향으로 회전하고 한칸 전진. 없다면 왼쪽으로 회전만 수행
#  네 방향 모두 가본 칸 or 바다로 된 칸이라면 방향을 유지하고 한칸 뒤로. 이떄 뒤쪽 방향이 바다라면 움직임을 멈춘다.

steps = [(0, -1), (1, 0), (0, 1), (-1, 0)]

result = 0
check = 1
game_map[cha_x][cha_y] = 2

while(True):
    if char_point(cha_p) == 0 :
        if game_map[cha_x][cha_y - 1] == 0 :
            game_map[cha_x][cha_y - 1] = 2 # 2는 육지이지만 가보았던 곳.
            cha_p = char_point(cha_p)
            cha_y -= 1
            result += 1
    elif char_point(cha_p) == 1 :
        if game_map[cha_x + 1][cha_y] == 0 :
            game_map[cha_x + 1][cha_y] = 2 # 2는 육지이지만 가보았던 곳.
            cha_p = char_point(cha_p)
            cha_x += 1
            result += 1
    elif char_point(cha_p) == 2 :
        if game_map[cha_x][cha_y + 1] == 0 :
            game_map[cha_x][cha_y + 1] = 2 # 2는 육지이지만 가보았던 곳.
            cha_p = char_point(cha_p)
            cha_y += 1
            result += 1
    elif char_point(cha_p) == 3 :
        if game_map[cha_x - 1][cha_y] == 0 :
            game_map[cha_x - 1][cha_y] = 2 # 2는 육지이지만 가보았던 곳.
            cha_p = char_point(cha_p)
            cha_x -= 1
            result += 1
    else :
        check = 0
        cha_x, cha_y = char_p_rev(cha_x, cha_y, cha_p)
        if game_map[cha_x + 1][cha_y] != 0 and game_map[cha_x - 1][cha_y] != 0 and game_map[cha_x][cha_y + 1] != 0 and game_map[cha_x][cha_y - 1] != 0 :
            break
    
print(game_map)
print(result)
# Out:
# 4 4
# 1 1 0
# 1 1 1 1
# 1 0 0 1
# 1 1 0 1
# 1 1 1 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-3c1e5d79e560> in <module>
#      63             cha_y += 1
#      64             result += 1
# ---> 65     elif char_point(cha_p) == 3 :
#      66         if game_map[cha_x - 1][cha_y] == 0 :
#      67             game_map[cha_x - 1][cha_y] = 2 # 2는 육지이지만 가보았던 곳.
#
# KeyboardInterrupt:

# %%
# 4 - 4 해설

n, m = map(int, input().split())

# 방문한 위치를 저장하기 위한 맵을 생성하여 0으로 초기화
d = [[0] * m for _ in range(n)]

# 현재 캐릭터의 X, Y, 방향을 입력받기

x, y, direction = map(int, input().split())
d[x][y] = 1

array = []
for i in range(n):
    array.append(list(map(int, input().split())))
    
dx = [-1, 0, 1, 0]
dy = [0, 1, 0, -1]

def turn_left():
    global direction
    direction -= 1
    if direction == -1 :
        direction = 3
        
count = 1
turn_time = 0
while True:
    turn_left()
    nx = x + dx[direction]
    ny = y + dy[direction]
    
    if d[nx][ny] == 0 and array[nx][ny] == 0 :
        d[nx][ny] = 1
        x= nx
        y = ny
        count += 1
        turn_time = 0
        continue
    else :
        turn_time += 1
    
    if turn_time == 4:
        nx = x - dx[direction]
        ny = y - dy[direction]
        
        if array[nx][ny] == 0:
            x = nx
            y = ny
        
        else :
            break
        turn_time = 0
        
        
print(count)
# Out:
# 4 4
# 1 1 0
# 1 1 1 1
# 1 0 0 1
# 1 1 0 1
# 1 1 1 1
# 3
